# %% [markdown]
# <a href="https://colab.research.google.com/github/josemarsoares/EnigmaVHDL/blob/main/Lista_de_ServoMec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![q1.png](data:image/png;base64,...)

# %% [markdown]
# <h1> Comprimento </h1>
# 1 cm - 0,01m
# <p>
# 1 in - 2,54 cm - 0,0254 m
# <p>
#
# 1cm² - 1,55 in² - 0,0001 m²
#
# 1ft² - 0,092903 m²
#
# 1Kg - 2,20462 Lbm - 0,0685218 slug
#
# 1Kgf - 9,80665 N - 2,20462 lbf
#
# 1N/m² - 1 Pa - 0,000145038 PSI - 47,88 lbf/Ft²
#
# 1Nm - 0,737562 lbf ft -10,1972 Ncm
#
# 1J - 1 Nm - 0,737 lbf ft
#
# 1Kg m²/S³ - 1 J/s - 1 W - 0.00134 hp
#
# 1° - 1 rad - 1 rev
#
# 1°C -33,8 F - 274,15 K

# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %% [markdown]
# ![pressao-o-que-e-definicao-caracteristicas-principais-tipos-e-formulas-1024x564[1].jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Dados da piramide:
#
# W = 650N
# a = 0,7m
#
# Dados da Esfera:
#
# W= 35 Kg Convertendo p/ g= 9,81
#
# W = 343,35 N
#
# Calculando:
#
# P = (M1 + M2)/A²
#
# Código:

# %%
w1=650
a=0.7

w2 = 343.35

p=(w1+w2)/(a**2)

print(f'P= {p:,.2f} n/m²')
# Out:
# P= 2,027.24 n/m²

# %% [markdown]
# ![q3.png](data:image/png;base64,...)

# %% [markdown]
# ![R3.png](data:image/png;base64,...)

# %% [markdown]
# ![q4.png](data:image/png;base64,...)

# %% [markdown]
# ![q4_2.png](data:image/png;base64,...)

# %% [markdown]
# W=20N
#
# F=100N
#
# Θ=30°
#
# Fm1 = F * L * senΘ
#
# código:
